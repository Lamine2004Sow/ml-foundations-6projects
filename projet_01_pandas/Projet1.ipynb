# %% [markdown]
# # Projet 1 — Pandas avancé sur données temporelles
#
# > **Dataset :** Historique Vélib (open data, gratuit)

# %% [markdown]
# ## Objectif
#
# Maîtriser les opérations pandas qui reviendront **constamment** dans ton stage :
# `groupby`, `merge`, `resample`, `rolling`.
#
# La structure des données Vélib est **identique** à celle de tes PBO :
# - une entité (station ↔ PBO)
# - un historique d'occupation dans le temps (vélos ↔ clients)
# - une capacité fixe (bornes ↔ ports fibres)

# %% [markdown]
# ## Mise en place

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Chargement
df = pd.read_csv("/home/zeyrox/Bureau/ml-foundations-6projects/data/historique_stations.csv")

# Premier regard
print(df.shape)
print(df.dtypes)
print(df.head())
print(df.isnull().sum())
# Out:
# (10986729, 7)
# 2020-11-26T12:59Z                  str
# 35                               int64
# 4                                int64
# 5                                int64
# Benjamin Godard - Victor Hugo      str
# 48.86598,2.27572                   str
# True                              bool
# dtype: object
#    2020-11-26T12:59Z  35   4   5        Benjamin Godard - Victor Hugo  \
# 0  2020-11-26T12:59Z  55  23   4   André Mazet - Saint-André des Arts
# 1  2020-11-26T12:59Z  20   0   0  Charonne - Robert et Sonia Delauney
# 2  2020-11-26T12:59Z  21   0   1                   Toudouze - Clauzel
# 3  2020-11-26T12:59Z  30   3   1                      Mairie du 12ème
# 4  2020-11-26T12:59Z  46  18  10                Harpe - Saint-Germain
#
#    48.86598,2.27572  True
# 0  48.85376,2.33910  True
# 1  48.85591,2.39257  True
# 2  48.87930,2.33736  True
# 3  48.84086,2.38755  True
# 4  48.85152,2.34367  True
# 2020-11-26T12:59Z                0
# 35                               0
# ...
